# %%
### More pandas practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# I'm going to use the telco dataset as practice to create dataframes and hoepfully some charts.

# %%
# Importing the data file as a pandas dataframe

# %%
titanic = pd.read_csv('titanic_db.csv', index_col=0)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 784                 0       3
# 2                   1       1
# 10                  1       2
# 20                  1       3
# 27                  0       3
# ...               ...     ...
# 888                 1       1
# 889                 0       3
# 441                 1       2
# 62                  1       1
# 830                 1       1
#
#                                                           Name    lastname  \
# PassengerId
# 784                                     Johnston, Mr. Andrew G    Johnston
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...     Cumings
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      Nasser
# 20                                     Masselmani, Mrs. Fatima  Masselmani
# 27                                     Emir, Mr. Farred Chehab        Emir
# ...                                                        ...         ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 784 to 830
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    int64
#  2   Name        891 non-null    object
#  3   lastname    891 non-null    object
#  4   title       891 non-null    object
#  5   first       891 non-null    object
#  6   Sex         891 non-null    object
#  7   Age         714 non-null    float64
#  8   FamilySize  891 non-null    int64
#  9   SibSp       891 non-null    int64
#  10  Parch       891 non-null    int64
#  11  Ticket      891 non-null    object
#  12  Fare        891 non-null    float64
#  13  Cabin       204 non-null    object
#  14  Embarked    888 non-null    object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 111.4+ KB

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age  FamilySize       SibSp       Parch  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    1.906846    0.523008    0.381594
# std      0.486592    0.836071   14.526497    1.612893    1.102743    0.806057
# min      0.000000    1.000000    0.420000    1.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    1.000000    0.000000    0.000000
# 50%      0.000000    3.000000   28.000000    1.000000    0.000000    0.000000
# 75%      1.000000    3.000000   38.000000    2.000000    1.000000    0.000000
# max      1.000000    3.000000   80.000000   11.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
details = pd.read_csv('CustDetails.csv')

# %%
details
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
details.round(details.total_charges / details.monthly_charges)
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
details['tenure'] = (details.total_charges / details.monthly_charges)

# %%
details
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
details.tenure = details['tenure'].round(decimals=0)

# %%
details
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
sns.barplot(x = 'tenure', y='monthly_charges', data=details)

# %%
bbb

# %%
deets_hist = sns.distplot(details.monthly_charges)

# %%
deets_jointplot = sns.jointplot(data=details, x='tenure', y='monthly_charges', kind='reg', color='g')
